# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
path = "./csv/chordData00.csv"

df = pd.read_csv(path, index_col = 0);

df.columns = pd.MultiIndex.from_product([["Next Chord"], df.columns])
df.index = pd.MultiIndex.from_product([["First Chord"], df.index])


df
# Out:
#                 Next Chord                                                  \
#                         Cd  Cm  CM  CA C#d C#m C#M C#A  Dd  Dm  DM  DA Ebd
# First Chord Cd           6   9   6   6   5   5   5   4   5   4   3   2   7
#             Cm           7  14  14  15   3   1   1   3   6   3   3   3   8
#             CM           7  13  14  15   5   3   2   4   6   4   3   3   7
#             CA           7  10  11  13   5   7   7   7   3   3   2   2   5
#             C#d          5   3   3   7   5   7   5   5   6   6   6   5   6
#             C#m          4   1   1   6   4   8   8   9   3   1   1   3   5
#             C#M          4   1   1   5   4   7   8   9   5   3   2   4   5
#             C#A          3   2   2   4   4   6   7   9   5   7   7   7   3
#             Dd           4   4   4   3   4   3   3   6   5   7   5   5   5
#             Dm           3   1   3   2   4   1   1   6   4   8   8   9   3
# ...
